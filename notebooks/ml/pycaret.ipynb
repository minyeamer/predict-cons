# %% [markdown]
# # Pycaret

# %%
# pip install pycaret==2.3.10

# %%
# pip install jinja2==3.1.2

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/MyDrive/customer')

import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import customer_data

from pycaret import regression
from pycaret.regression import setup, create_model, compare_models
from pycaret.regression import blend_models, predict_model, finalize_model
# Out:
# Mounted at /content/drive

# %%
train, test, _, _ = customer_data.load_data(test_size=0,encoding=False)
train.drop(['id'], axis=1, inplace=True)
train.head()
# Out:
#    AcceptedCmp1  AcceptedCmp2  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  Age  \
# 0             0             0             0             0             0   48
# 1             0             0             1             0             0   60
# 2             0             0             0             0             0   71
# 3             0             0             0             0             0   48
# 4             1             0             0             0             0   76
#
#    Age_Range  Complain  Days_Customer  Education   Income  Income_Level  \
# 0          4         0           3267          3  46014.0      0.283343
# 1          6         0           2779          2  76624.0      0.775727
# 2          7         0           3190          2  75903.0      0.667373
# 3          4         0           2835          1  18393.0      0.113259
# 4          7         0           2762          4  64014.0      0.562840
#
#    Income_Per  Kidhome  Marital_Status  NumAcceptedCmp  NumCatalogPurchases  \
# 0     23007.0        1               3               0                    1
# 1     76624.0        0               2               1                   10
# 2     75903.0        0               1               0                    6
# 3      9196.5        1               1               0                    0
# 4     21338.0        2               3               1                    2
#
#    NumDealsPurchases  NumPurchases  NumStorePurchases  NumWebPurchases  \
# 0                 10            16                  8                7
# 1                  1            22                  7                5
# 2                  2            21                  9                6
# 3                  2             6                  3                3
# 4                  7            15                  5                8
#
#    NumWebVisitsMonth  Perferred_Purchase  Recency  Response  Teenhome  target
# 0                  7                   2       21         0         1     541
# 1                  1                   1       68         0         1     899
# 2                  3                   2       50         0         1     901
# 3                  8                   0        2         0         0      50
# 4                  7                   0       56         0         1     444

# %%
model = regression.setup(data=train, target='target',train_size=0.7,session_id=0,silent=True)
# Out:
#                                Description             Value
# 0                               session_id                 0
# 1                                   Target            target
# 2                            Original Data        (1102, 27)
# 3                           Missing Values             False
# 4                         Numeric Features                 7
# 5                     Categorical Features                19
# 6                         Ordinal Features             False
# 7                High Cardinality Features             False
# 8                  High Cardinality Method              None
# 9                    Transformed Train Set        (771, 112)
# 10                    Transformed Test Set        (331, 112)
# 11                      Shuffle Train-Test              True
# 12                     Stratify Train-Test             False
# 13                          Fold Generator             KFold
# 14                             Fold Number                10
# 15                                CPU Jobs                -1
# 16                                 Use GPU             False
# 17                          Log Experiment             False
# 18                         Experiment Name  reg-default-name
# 19                                     USI              5310
# 20                         Imputation Type            simple
# 21          Iterative Imputation Iteration              None
# 22                         Numeric Imputer              mean
# 23      Iterative Imputation Numeric Model              None
# 24                     Categorical Imputer          constant
# 25  Iterative Imputation Categorical Model              None
# 26           Unknown Categoricals Handling    least_frequent
# 27                               Normalize             False
# 28                        Normalize Method              None
# 29                          Transformation             False
# 30                   Transformation Method              None
# 31                                     PCA             False
# 32                              PCA Method              None
# 33                          PCA Components              None
# 34                     Ignore Low Variance             False
# 35                     Combine Rare Levels             False
# 36                    Rare Level Threshold              None
# 37                         Numeric Binning             False
# 38                         Remove Outliers             False
# 39                      Outliers Threshold              None
# 40                Remove Multicollinearity             False
# 41             Multicollinearity Threshold              None
# 42             Remove Perfect Collinearity              True
# 43                              Clustering             False
# 44                    Clustering Iteration              None
# 45                     Polynomial Features             False
# 46                       Polynomial Degree              None
# 47                    Trignometry Features             False
# 48                    Polynomial Threshold              None
# 49                          Group Features             False
# 50                       Feature Selection             False
# 51                Feature Selection Method           classic
# 52            Features Selection Threshold              None
# 53                     Feature Interaction             False
# 54                           Feature Ratio             False
# 55                   Interaction Threshold              None
# 56                        Transform Target             False
# 57                 Transform Target Method           box-cox

# %%
top_3_models = regression.compare_models(sort='MAE', n_select=3)
# Out:
#                                     Model           MAE           MSE  \
# et                  Extra Trees Regressor  1.135424e+02  4.397990e+04
# rf                Random Forest Regressor  1.181492e+02  4.429187e+04
# lightgbm  Light Gradient Boosting Machine  1.231632e+02  4.640878e+04
# gbr           Gradient Boosting Regressor  1.281412e+02  4.958125e+04
# dt                Decision Tree Regressor  1.609509e+02  9.167058e+04
# lasso                    Lasso Regression  1.641405e+02  5.602583e+04
# br                         Bayesian Ridge  1.650330e+02  5.637430e+04
# ridge                    Ridge Regression  1.675767e+02  5.844351e+04
# llar         Lasso Least Angle Regression  1.741903e+02  6.112755e+04
# lr                      Linear Regression  1.776311e+02  6.301187e+04
# omp           Orthogonal Matching Pursuit  1.786122e+02  6.331641e+04
# en                            Elastic Net  1.872277e+02  6.555318e+04
# knn                 K Neighbors Regressor  2.000579e+02  8.570580e+04
# ada                    AdaBoost Regressor  2.104250e+02  6.990251e+04
# huber                     Huber Regressor  2.210208e+02  9.957576e+04
# par          Passive Aggressive Regressor  3.449782e+02  2.592233e+05
# dummy                     Dummy Regressor  5.223951e+02  3.689986e+05
# lar                Least Angle Regression  1.745215e+17  1.293135e+37
#
#                   RMSE            R2    RMSLE          MAPE  TT (Sec)
# et        2.066704e+02  8.778000e-01   0.2640  2.099000e-01     0.903
# rf        2.069502e+02  8.758000e-01   0.2643  2.102000e-01     0.930
# lightgbm  2.126591e+02  8.693000e-01   0.3750  2.576000e-01     0.113
# gbr       2.202284e+02  8.605000e-01   0.3764  3.356000e-01     0.250
# dt        2.976864e+02  7.465000e-01   0.3769  2.683000e-01     0.028
# lasso     2.336813e+02  8.413000e-01   0.7914  1.102900e+00     0.032
# br        2.343831e+02  8.403000e-01   0.7640  1.151000e+00     0.028
# ridge     2.385175e+02  8.352000e-01   0.7668  1.076100e+00     0.014
# llar      2.445372e+02  8.288000e-01   0.7432  1.073300e+00     0.018
# lr        2.474458e+02  8.228000e-01   0.8062  1.314200e+00     0.330
# omp       2.490637e+02  8.224000e-01   0.7699  1.098700e+00     0.016
# en        2.540172e+02  8.148000e-01   0.7923  1.435300e+00     0.020
# knn       2.912686e+02  7.551000e-01   0.7297  8.764000e-01     0.069
# ada       2.630805e+02  8.010000e-01   0.9679  1.768000e+00     0.182
# huber     3.109579e+02  7.269000e-01   0.8281  1.210000e+00     0.093
# par       5.011933e+02  2.931000e-01   1.1815  9.586000e-01     0.020
# dummy     6.045586e+02 -2.860000e-02   1.6468  5.697600e+00     0.012
# lar       1.510858e+18 -3.190242e+31  19.8363  1.879247e+15     0.043

# %%
blended = regression.blend_models(estimator_list=top_3_models, fold=10, optimize='MAE')
# Out:
#            MAE         MSE      RMSE      R2   RMSLE    MAPE
# Fold
# 0     114.0313  49852.0871  223.2758  0.8640  0.2802  0.2193
# 1     102.4342  27716.4664  166.4826  0.9181  0.2237  0.1854
# 2     119.0809  45830.4971  214.0806  0.8884  0.2028  0.1546
# 3      97.0507  24808.0359  157.5057  0.8842  0.2374  0.1959
# 4      89.5628  25772.5426  160.5383  0.9379  0.1991  0.1485
# 5     124.0340  45562.9195  213.4547  0.8919  0.2903  0.2355
# 6      95.8976  31273.6782  176.8437  0.9085  0.2555  0.2007
# 7     104.1613  39274.4346  198.1778  0.8774  0.2895  0.2530
# 8     119.6637  53408.6753  231.1032  0.8202  0.3984  0.2685
# 9     171.0532  75910.2341  275.5181  0.8388  0.2761  0.2219
# Mean  113.6970  41940.9571  201.6980  0.8829  0.2653  0.2083
# Std    22.0351  15014.8106   35.4804  0.0336  0.0549  0.0372

# %%
final_blended = regression.finalize_model(blended)
pred_train = regression.predict_model(final_blended, data=train)
true_pred = pd.DataFrame([train['target'],pred_train['Label']]).T
true_pred.head()
# Out:
#               Model      MAE       MSE     RMSE     R2   RMSLE    MAPE
# 0  Voting Regressor  26.0224  2191.203  46.8103  0.994  0.0975  0.0627
#    target       Label
# 0   541.0  545.689672
# 1   899.0  914.717236
# 2   901.0  970.166690
# 3    50.0   47.799308
# 4   444.0  471.412134

# %%
plt.style.use('ggplot')
plt.figure(figsize=(20, 8))
plt.plot(true_pred['Label'], label='pred')
plt.plot(true_pred['target'], label='true')
plt.legend(fontsize=20)
plt.show()

# %%
regression.save_model(final_blended, 'model_pycaret')

# %%
from google.colab import files
files.download('model_pycaret.pkl')
